# %%
import numpy as np
import pandas as pd
print(np.__version__)   # should print 1.26.4
print(pd.__version__)   # should print 2.2.2
# Press Shift+Enter — green checkmark = success
# Out:
# 1.26.4
# 2.2.2
